# %%
import pandas as pd
import matplotlib.pyplot as plt

full_data_file=pd.read_csv('car_purchasing.csv',header=0,encoding='latin-1')
full_data_file
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
#Extrasión de datos que utilizaremos
data_file=pd.read_csv('car_purchasing.csv',usecols=[5,8], encoding='latin-1')
data_file
# Out:
#      annual Salary  car purchase amount
# 0      62812.09301          35321.45877
# 1      66646.89292          45115.52566
# 2      53798.55112          42925.70921
# 3      79370.03798          67422.36313
# 4      59729.15130          55915.46248
# ..             ...                  ...
# 495    71942.40291          48901.44342
# 496    56039.49793          31491.41457
# 497    68888.77805          64147.28888
# 498    49811.99062          45442.15353
# 499    61370.67766          45107.22566
#
# [500 rows x 2 columns]

# %%
data_file.corr()
# Out:
#                      annual Salary  car purchase amount
# annual Salary             1.000000             0.617862
# car purchase amount       0.617862             1.000000

# %%
mean_data = data_file.mean(0)
mean_data
# Out:
# annual Salary          62127.239608
# car purchase amount    44209.799218
# dtype: float64

# %%
plt.scatter(data_file['annual Salary'],data_file['car purchase amount'],c='DarkBlue')
plt.xlabel('Variable Independiente')
plt.ylabel('Variable Dependiente')
plt.legend()
plt.show()
mean_data = data_file.mean(0)
plt.scatter(mean_data['annual Salary'],mean_data['car purchase amount'],c='Red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7ba77af5cdc6> in <cell line: 1>()
# ----> 1 plt.scatter(data_file['annual Salary'],data_file['car purchase amount'],c='DarkBlue')
#       2 plt.xlabel('Variable Independiente')
#       3 plt.ylabel('Variable Dependiente')
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from sklearn.linear_model import LinearRegression
# Crear un modelo de regresión lineal
modelo = LinearRegression()

X = data_file['annual Salary'].values.reshape(-1, 1) # Variable independiente
Y = data_file['car purchase amount']#.values.reshape(-1, 1) # Variable dependependiente
# Ajustar el modelo a los datos
modelo.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Hacer predicciones
y_pred = modelo.predict(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-92ac0d1fa86a> in <cell line: 2>()
#       1 # Hacer predicciones
# ----> 2 y_pred = modelo.predict(X)
#
# NameError: name 'modelo' is not defined

# %%
# Graficar los datos y la regresión lineal
plt.scatter(X, Y, label='Datos',color='DarkBlue')
plt.plot(X, y_pred, color='red', label='Regresión Lineal')
plt.xlabel('Variable Independiente')
plt.ylabel('Variable Dependiente')
plt.legend()
plt.show()

# %%
modelo.coef_
# Out:
# array([0.56875325])

# %%
modelo.intercept_
# Out:
# 8874.72947262624
